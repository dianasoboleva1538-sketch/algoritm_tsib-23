# %% [markdown]
# <a href="https://colab.research.google.com/github/dianasoboleva1538-sketch/algoritm_tsib-23/blob/main/%D0%90%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D1%8B_1_%D0%9B%D0%A0_%D0%A6%D0%98%D0%91_251.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Курс: ЦИБ - 251
#Обучающийся: Соболева Д.Ю.
#Задание 23: Сортировка содержимого стека (используя только один дополнительный стек)
def sort_stack(stack):
    temp_stack = []
    while stack:
        temp = stack.pop()
        while temp_stack and temp_stack[-1] > temp:
            stack.append(temp_stack.pop())
        temp_stack.append(temp)
    while temp_stack:
        stack.append(temp_stack.pop())
    return stack
if __name__ == "__main__":
    stack = [5, 1, 4, 2, 8]
    print("Исходный стек:", stack)
    sort_stack(stack)
    print("Отсортированный стек (сверху минимальный):", stack)
# Out:
# Исходный стек: [5, 1, 4, 2, 8]
# Отсортированный стек (сверху минимальный): [8, 5, 4, 2, 1]

# %% [markdown]
# ![Снимок экрана 2026-04-08 111857.png](data:image/png;base64,...)
